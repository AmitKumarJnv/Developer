# %% [markdown]
# #### Standard python type
# - str
# - int
# - float
# - bool
# - bytes
#
# ##### Generic types
# - List
# - set
# - tuple
# - dict

# %%
def processing_list(input_list: list[str],item_tuple : tuple[int], item_set: set[bytes],item_dict: dict[str, float])-> str:
    pass

# %%
from typing import Union

def process_item(item: Union[int,str]):
    print(item)
