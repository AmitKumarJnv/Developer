# %% [markdown]
# ## Python Tutorial

# %%
print("Hello world")
# Out:
# Hello world

# %%
import sys

print(sys.version)
# Out:
# 3.10.2 (v3.10.2:a58ebcc701, Jan 13 2022, 14:50:16) [Clang 13.0.0 (clang-1300.0.29.30)]

# %%
import sys
sys.stdout.write('Geeks for geeks')
# Out:
# Geeks for geeks
# 15
