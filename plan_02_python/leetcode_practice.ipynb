# %% [markdown]
# ### Merge Sorted Arrays

# %%
arr_01 = [1,4,8]
arr_02 = [2,3,5,9]
merged_arr = list()

for i in range(len(arr_01)-1):
    print((arr_01[i],arr_01[i+1]))
# Out:
# (1, 4)
# (4, 8)

# %%
for i in range(len(arr_01)):
    for j in range(len(arr_02)):
        if arr_01[i]<arr_02[j]:
            merged_arr.append(arr_01[i])
            i+=1
        elif arr_01[i]>arr_02[j]:
            merged_arr.append(arr_02[j])
            j+=1  
        else:
            merged_arr.append([arr_01[i],arr_02[j]])
            i+=1
            j+=1

# Observation: wrong assumption that for loop will work, trying with while loop now

# %%
merged_arr
# Out:
# [1, 3, 4, 8, 2, 3, 4, 8, 2, 3, 5, 8]

# %%
arr_01_length = len(arr_01)
arr_02_length = len(arr_02)
i,j=0,0

# %%
# arr_01 = [1,4,8]
# arr_02 = [2,3,5,9]

# arr_02 = [1,4,8]
# arr_01 = [2,3,5,9]

# arr_02 = [0,1,4,6,8,10]
# arr_01 = [2,3,5,7,9]

# arr_02 = [-1,2,4,8]
# arr_01 = [-2,2,3,5,9]

arr_02 = [4,8]
arr_01 = [-2,2,3,5,9]

merged_arr = list()

arr_01_length = len(arr_01)
arr_02_length = len(arr_02)
i,j=0,0

while i < arr_01_length and j < arr_02_length:
    if arr_01[i]<arr_02[j]:
        merged_arr.append(arr_01[i])
        i+=1
    elif arr_01[i]>arr_02[j]:
        merged_arr.append(arr_02[j])
        j+=1  
    else:
        merged_arr.append(arr_01[i])
        merged_arr.append(arr_02[j])
        i+=1
        j+=1  

while i < arr_01_length:
    merged_arr.append(arr_01[i])
    i += 1

while j < arr_02_length:
    merged_arr.append(arr_02[j])
    j += 1        

merged_arr
# Out:
# [-2, 2, 3, 4, 5, 8, 9]
